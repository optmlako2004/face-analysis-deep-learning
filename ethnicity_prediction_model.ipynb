# %% [markdown]
# # Modèle Spécialisé - Prédiction d'Ethnicité
#
# Ce notebook implémente un modèle de deep learning spécialisé dans la classification de l'ethnicité à partir de photos de visages.
#
# **Architecture:** Transfer Learning avec EfficientNetB0
# **Tâche:** Classification multi-classe (5 classes)
# **Dataset:** UTKFace (23,708 images)
#
# **Classes:**
#
# - 0: White
# - 1: Black
# - 2: Asian
# - 3: Indian
# - 4: Others

# %% [markdown]
# ## 1. Configuration et Imports

# %%
import os
import warnings

warnings.filterwarnings("ignore")

# Configuration GPU
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from tqdm.auto import tqdm
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, callbacks
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import CosineDecay

# Configuration
print(f"TensorFlow version: {tf.__version__}")
print(f"GPU disponible: {tf.config.list_physical_devices('GPU')}")

# Permettre la croissance mémoire GPU
gpus = tf.config.list_physical_devices("GPU")
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# Seed pour reproductibilité
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Style des graphiques
sns.set_theme(style="whitegrid", context="notebook")
plt.rcParams.update({"figure.figsize": (10, 5), "axes.titlesize": 14})
# Out:
# TensorFlow version: 2.20.0
# GPU disponible: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Constantes et Hyperparamètres

# %%
# Chemins
BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / "data" / "UTKFace"
ARTIFACTS_DIR = BASE_DIR / "artifacts"
ARTIFACTS_DIR.mkdir(exist_ok=True)

# Classes d'ethnicité
ETHNICITY_MAP = {0: "White", 1: "Black", 2: "Asian", 3: "Indian", 4: "Others"}
NUM_CLASSES = len(ETHNICITY_MAP)
CLASS_NAMES = list(ETHNICITY_MAP.values())

# Hyperparamètres
IMG_SIZE = 128
BATCH_SIZE = 32
WARMUP_EPOCHS = 15
FINETUNE_EPOCHS = 35
INITIAL_LR = 1e-3
FINETUNE_LR = 1e-5

# Validation
VAL_SPLIT = 0.1
TEST_SPLIT = 0.1

print(f"Configuration:")
print(f"  - Classes: {CLASS_NAMES}")
print(f"  - Image size: {IMG_SIZE}x{IMG_SIZE}")
print(f"  - Batch size: {BATCH_SIZE}")
# Out:
# Configuration:
#   - Classes: ['White', 'Black', 'Asian', 'Indian', 'Others']
#   - Image size: 128x128
#   - Batch size: 32

# %% [markdown]
# ## 3. Chargement des Données

# %%
def parse_utkface_filename(filepath: Path) -> dict | None:
    """Parse les métadonnées depuis le nom de fichier UTKFace."""
    try:
        name = filepath.name.split(".")[0]
        parts = name.split("_")
        if len(parts) < 3:
            return None

        ethnicity = int(parts[2]) if parts[2].isdigit() else -1

        # Filtrer les ethnicités invalides
        if ethnicity < 0 or ethnicity > 4:
            return None

        return {
            "filepath": str(filepath),
            "ethnicity": ethnicity,
            "ethnicity_name": ETHNICITY_MAP.get(ethnicity, "Unknown"),
        }
    except Exception:
        return None


# Charger toutes les images
image_paths = list(DATA_DIR.glob("*.jpg*"))
print(f"Images trouvées: {len(image_paths)}")

# Parser les métadonnées
records = []
for path in tqdm(image_paths, desc="Parsing des fichiers"):
    record = parse_utkface_filename(path)
    if record:
        records.append(record)

df = pd.DataFrame(records)
print(f"\nImages valides: {len(df)}")
# Out:
# Images trouvées: 23708
# Parsing des fichiers: 100%|██████████| 23708/23708 [00:00<00:00, 1417877.14it/s]
# Images valides: 23705

# %%
# Distribution des classes
print("Distribution des ethnicités:")
class_counts = df["ethnicity_name"].value_counts()
print(class_counts)

# Visualisation
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Bar plot
colors = plt.cm.Set2(np.linspace(0, 1, NUM_CLASSES))
class_counts_sorted = df["ethnicity"].value_counts().sort_index()
axes[0].bar(
    [ETHNICITY_MAP[i] for i in class_counts_sorted.index],
    class_counts_sorted.values,
    color=colors,
    edgecolor="black",
)
axes[0].set_xlabel("Ethnicité")
axes[0].set_ylabel("Nombre d'images")
axes[0].set_title("Distribution des classes")
for i, v in enumerate(class_counts_sorted.values):
    axes[0].text(i, v + 100, str(v), ha="center", fontsize=10)

# Pie chart
axes[1].pie(
    class_counts_sorted.values,
    labels=[ETHNICITY_MAP[i] for i in class_counts_sorted.index],
    autopct="%1.1f%%",
    colors=colors,
    startangle=90,
)
axes[1].set_title("Répartition des ethnicités")

plt.tight_layout()
plt.show()

# Calcul du déséquilibre
imbalance_ratio = class_counts.max() / class_counts.min()
print(f"\nRatio de déséquilibre max/min: {imbalance_ratio:.2f}")
# Out:
# Distribution des ethnicités:
# ethnicity_name
# White     10078
# Black      4526
# Indian     3975
# Asian      3434
# Others     1692
# Name: count, dtype: int64
# Ratio de déséquilibre max/min: 5.96

# %% [markdown]
# ## 4. Split Train/Validation/Test (Stratifié)

# %%
# Split stratifié
X = df["filepath"].values
y = df["ethnicity"].values

# Premier split: train+val vs test
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=TEST_SPLIT, stratify=y, random_state=SEED
)

# Deuxième split: train vs val
X_train, X_val, y_train, y_val = train_test_split(
    X_temp,
    y_temp,
    test_size=VAL_SPLIT / (1 - TEST_SPLIT),
    stratify=y_temp,
    random_state=SEED,
)

print(f"Split des données:")
print(f"  - Train: {len(X_train)} ({len(X_train)/len(X)*100:.1f}%)")
print(f"  - Validation: {len(X_val)} ({len(X_val)/len(X)*100:.1f}%)")
print(f"  - Test: {len(X_test)} ({len(X_test)/len(X)*100:.1f}%)")

# Vérifier la stratification
print(f"\nDistribution dans le train set:")
unique, counts = np.unique(y_train, return_counts=True)
for u, c in zip(unique, counts):
    print(f"  - {ETHNICITY_MAP[u]}: {c} ({c/len(y_train)*100:.1f}%)")
# Out:
# Split des données:
#   - Train: 18963 (80.0%)
#   - Validation: 2371 (10.0%)
#   - Test: 2371 (10.0%)
#
# Distribution dans le train set:
#   - White: 8062 (42.5%)
#   - Black: 3620 (19.1%)
#   - Asian: 2748 (14.5%)
#   - Indian: 3179 (16.8%)
#   - Others: 1354 (7.1%)

# %% [markdown]
# ## 5. Calcul des Poids de Classes

# %%
# Calculer les poids de classes pour gérer le déséquilibre
class_weights_array = compute_class_weight(
    class_weight="balanced", classes=np.unique(y_train), y=y_train
)
class_weights = dict(enumerate(class_weights_array))

print("Poids des classes:")
for cls, weight in class_weights.items():
    print(f"  - {ETHNICITY_MAP[cls]}: {weight:.3f}")
# Out:
# Poids des classes:
#   - White: 0.470
#   - Black: 1.048
#   - Asian: 1.380
#   - Indian: 1.193
#   - Others: 2.801

# %% [markdown]
# ## 7. Pipeline de Données avec Data Augmentation

# %%
# Couche de data augmentation
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.15),
        layers.RandomTranslation(0.1, 0.1),
        layers.RandomBrightness(0.2),
        layers.RandomContrast(0.2),
    ],
    name="data_augmentation",
)


def load_and_preprocess(filepath, label):
    """Charge et prétraite une image (sans normalisation pour permettre l'augmentation)."""
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32)
    return img, label


def create_dataset(filepaths, labels, batch_size, shuffle=True, augment=False):
    """Crée un tf.data.Dataset."""
    ds = tf.data.Dataset.from_tensor_slices((filepaths, labels))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(filepaths), seed=SEED)

    ds = ds.map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size)

    if augment:
        ds = ds.map(
            lambda x, y: (data_augmentation(x, training=True), y),
            num_parallel_calls=tf.data.AUTOTUNE,
        )

    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds


# Créer les datasets
train_ds = create_dataset(X_train, y_train, BATCH_SIZE, shuffle=True, augment=True)
val_ds = create_dataset(X_val, y_val, BATCH_SIZE, shuffle=False, augment=False)
test_ds = create_dataset(X_test, y_test, BATCH_SIZE, shuffle=False, augment=False)

print("Datasets créés avec succès!")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768735453.931787   31949 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4081 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Datasets créés avec succès!

# %%
# Visualiser quelques exemples
fig, axes = plt.subplots(2, 4, figsize=(16, 8))

for images, labels in train_ds.take(1):
    for i, ax in enumerate(axes.flat):
        if i < len(images):
            # Images sont en [0, 255], normaliser pour affichage
            img = images[i].numpy() / 255.0
            img = np.clip(img, 0, 1)
            ax.imshow(img)
            ax.set_title(f"{ETHNICITY_MAP[labels[i].numpy()]}")
            ax.axis("off")

plt.suptitle("Exemples d'images par ethnicité", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Construction du Modèle

# %%
def build_ethnicity_model(
    img_size: int, num_classes: int, trainable_backbone: bool = False
) -> Model:
    """Construit le modèle de classification d'ethnicité avec EfficientNetB0."""

    inputs = layers.Input(shape=(img_size, img_size, 3), name="input_image")

    # Backbone EfficientNetB0
    backbone = EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_shape=(img_size, img_size, 3),
        pooling=None,
    )
    backbone.trainable = trainable_backbone

    x = backbone(inputs)

    # Double pooling (GAP + GMP) pour capturer plus d'informations
    gap = layers.GlobalAveragePooling2D(name="gap")(x)
    gmp = layers.GlobalMaxPooling2D(name="gmp")(x)
    x = layers.Concatenate(name="concat_pool")([gap, gmp])

    # Head de classification
    x = layers.Dense(256, activation="relu", name="dense_1")(x)
    x = layers.BatchNormalization(name="bn_1")(x)
    x = layers.Dropout(0.5, name="dropout_1")(x)

    x = layers.Dense(128, activation="relu", name="dense_2")(x)
    x = layers.BatchNormalization(name="bn_2")(x)
    x = layers.Dropout(0.4, name="dropout_2")(x)

    # Output (classification multi-classe)
    outputs = layers.Dense(num_classes, activation="softmax", name="ethnicity_output")(
        x
    )

    model = Model(inputs, outputs, name="EthnicityModel_EfficientNetB0")
    return model, backbone


# Construire le modèle
model, backbone = build_ethnicity_model(IMG_SIZE, NUM_CLASSES, trainable_backbone=False)
model.summary()
# Out:
# Model: "EthnicityModel_EfficientNetB0"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_image         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficientnetb0      │ (None, 4, 4,      │  4,049,571 │ input_image[0][0] │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 1280)      │          0 │ efficientnetb0[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gmp                 │ (None, 1280)      │          0 │ efficientnetb0[0… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_pool         │ (None, 2560)      │          0 │ gap[0][0],        │
# │ (Concatenate)       │                   │            │ gmp[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    655,616 │ concat_pool[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_1                │ (None, 256)       │      1,024 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ bn_1[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     32,896 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_2                │ (None, 128)       │        512 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ bn_2[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ethnicity_output    │ (None, 5)         │        645 │ dropout_2[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,740,264 (18.08 MB)
#  Trainable params: 689,925 (2.63 MB)
#  Non-trainable params: 4,050,339 (15.45 MB)

# %% [markdown]
# ## 9. Phase 1: Warmup (Backbone Gelé)

# %%
steps_per_epoch = len(X_train) // BATCH_SIZE
total_warmup_steps = steps_per_epoch * WARMUP_EPOCHS

warmup_lr_schedule = CosineDecay(
    initial_learning_rate=INITIAL_LR, decay_steps=total_warmup_steps, alpha=0.1
)

model.compile(
    optimizer=Adam(learning_rate=warmup_lr_schedule),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

warmup_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=10,
        restore_best_weights=True,
        mode="max",
        verbose=1,
    ),
    callbacks.ModelCheckpoint(
        filepath=str(ARTIFACTS_DIR / "ethnicity_warmup_best.keras"),
        monitor="val_accuracy",
        save_best_only=True,
        mode="max",
        verbose=1,
    ),
    # Note: Pas de ReduceLROnPlateau car CosineDecay gère déjà la décroissance du LR
]

print(f"Phase 1: Warmup ({WARMUP_EPOCHS} epochs, backbone gelé)")
print(
    f"Paramètres entraînables: {sum([tf.reduce_prod(w.shape).numpy() for w in model.trainable_weights]):,}"
)
# Out:
# Phase 1: Warmup (15 epochs, backbone gelé)
# Paramètres entraînables: 689,925

# %%
# Entraînement Phase 1
warmup_history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=WARMUP_EPOCHS,
    callbacks=warmup_callbacks,
    class_weight=class_weights,
    verbose=1,
)
# Out:
# Epoch 1/15
# 2026-01-18 12:24:29.502229: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:24:29.586918: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:24:29.998423: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:24:30.088064: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:24:30.512914: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:24:30.602246: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1768735474.895596   32034 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3357 - loss: 1.9346
# 2026-01-18 12:24:50.396681: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:24:50.481691: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:24:50.868893: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:24:50.958079: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:24:51.380984: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:24:51.470059: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3359 - loss: 1.9338
# 2026-01-18 12:25:04.110447: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:04.195052: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:04.279172: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:04.364635: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:04.449720: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:04.535029: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:04.619782: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:04.704344: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:04.788967: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:04.874861: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:05.241061: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:05.328888: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:05.417573: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:05.506737: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:05.594954: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:05.684665: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:05.774241: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:05.873907: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:05.960108: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:06.050148: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:06.475945: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:06.564506: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:25:06.653652: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_accuracy improved from None to 0.56348, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
#
# Epoch 1: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 52s 58ms/step - accuracy: 0.3862 - loss: 1.6928 - val_accuracy: 0.5635 - val_loss: 1.1651
# Epoch 2/15
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4760 - loss: 1.3806
# Epoch 2: val_accuracy improved from 0.56348 to 0.60017, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
#
# Epoch 2: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.4776 - loss: 1.3534 - val_accuracy: 0.6002 - val_loss: 1.0699
# Epoch 3/15
# 589/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5041 - loss: 1.3017
# Epoch 3: val_accuracy improved from 0.60017 to 0.60692, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
#
# Epoch 3: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.5127 - loss: 1.2848 - val_accuracy: 0.6069 - val_loss: 1.0459
# Epoch 4/15
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5248 - loss: 1.2426
# Epoch 4: val_accuracy improved from 0.60692 to 0.62041, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
#
# Epoch 4: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.5303 - loss: 1.2417 - val_accuracy: 0.6204 - val_loss: 1.0293
# Epoch 5/15
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5314 - loss: 1.2287
# Epoch 5: val_accuracy did not improve from 0.62041
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.5360 - loss: 1.2309 - val_accuracy: 0.6145 - val_loss: 1.0316
# Epoch 6/15
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5494 - loss: 1.2080
# Epoch 6: val_accuracy did not improve from 0.62041
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.5495 - loss: 1.2171 - val_accuracy: 0.6124 - val_loss: 1.0317
# Epoch 7/15
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5537 - loss: 1.2100
# Epoch 7: val_accuracy improved from 0.62041 to 0.62379, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
#
# Epoch 7: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.5588 - loss: 1.1945 - val_accuracy: 0.6238 - val_loss: 0.9986
# Epoch 8/15
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5557 - loss: 1.2022
# Epoch 8: val_accuracy did not improve from 0.62379
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.5587 - loss: 1.1878 - val_accuracy: 0.6229 - val_loss: 1.0110
# Epoch 9/15
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5650 - loss: 1.1736
# Epoch 9: val_accuracy improved from 0.62379 to 0.62590, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
#
# Epoch 9: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.5616 - loss: 1.1757 - val_accuracy: 0.6259 - val_loss: 0.9886
# Epoch 10/15
# 589/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5693 - loss: 1.1603
# Epoch 10: val_accuracy improved from 0.62590 to 0.63855, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
#
# Epoch 10: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.5664 - loss: 1.1606 - val_accuracy: 0.6385 - val_loss: 0.9694
# Epoch 11/15
# 589/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5731 - loss: 1.1529
# Epoch 11: val_accuracy did not improve from 0.63855
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.5734 - loss: 1.1519 - val_accuracy: 0.6352 - val_loss: 0.9711
# Epoch 12/15
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5686 - loss: 1.1508
# Epoch 12: val_accuracy did not improve from 0.63855
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.5691 - loss: 1.1483 - val_accuracy: 0.6385 - val_loss: 0.9699
# Epoch 13/15
# 589/593 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5739 - loss: 1.1558
# Epoch 13: val_accuracy did not improve from 0.63855
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.5734 - loss: 1.1450 - val_accuracy: 0.6381 - val_loss: 0.9615
# Epoch 14/15
# 589/593 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5813 - loss: 1.1424
# Epoch 14: val_accuracy improved from 0.63855 to 0.64572, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
#
# Epoch 14: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_warmup_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.5791 - loss: 1.1402 - val_accuracy: 0.6457 - val_loss: 0.9530
# Epoch 15/15
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5723 - loss: 1.1517
# Epoch 15: val_accuracy did not improve from 0.64572
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.5772 - loss: 1.1373 - val_accuracy: 0.6432 - val_loss: 0.9541
# Restoring model weights from the end of the best epoch: 14.

# %% [markdown]
# ## 10. Phase 2: Fine-tuning

# %%
# Dégeler les dernières couches du backbone
backbone.trainable = True

freeze_until = len(backbone.layers) - 50
for layer in backbone.layers[:freeze_until]:
    layer.trainable = False

trainable_count = sum(
    [tf.reduce_prod(w.shape).numpy() for w in model.trainable_weights]
)
print(f"Phase 2: Fine-tuning ({FINETUNE_EPOCHS} epochs)")
print(f"Couches dégelées: {len(backbone.layers) - freeze_until}/{len(backbone.layers)}")
print(f"Paramètres entraînables: {trainable_count:,}")
# Out:
# Phase 2: Fine-tuning (35 epochs)
# Couches dégelées: 50/238
# Paramètres entraînables: 3,216,789

# %%
total_finetune_steps = steps_per_epoch * FINETUNE_EPOCHS

finetune_lr_schedule = CosineDecay(
    initial_learning_rate=FINETUNE_LR, decay_steps=total_finetune_steps, alpha=0.01
)

model.compile(
    optimizer=Adam(learning_rate=finetune_lr_schedule),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

finetune_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=15,
        restore_best_weights=True,
        mode="max",
        verbose=1,
    ),
    callbacks.ModelCheckpoint(
        filepath=str(ARTIFACTS_DIR / "ethnicity_model_best.keras"),
        monitor="val_accuracy",
        save_best_only=True,
        mode="max",
        verbose=1,
    ),
    # Note: Pas de ReduceLROnPlateau car CosineDecay gère déjà la décroissance du LR
]

# %%
# Entraînement Phase 2
finetune_history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=FINETUNE_EPOCHS,
    callbacks=finetune_callbacks,
    class_weight=class_weights,
    verbose=1,
)
# Out:
# Epoch 1/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4304 - loss: 1.4770
# 2026-01-18 12:28:19.770066: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:28:19.857494: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:28:19.944320: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:28:20.032023: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4305 - loss: 1.4768
# Epoch 1: val_accuracy improved from None to 0.55715, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 1: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 48s 50ms/step - accuracy: 0.4534 - loss: 1.4164 - val_accuracy: 0.5571 - val_loss: 1.1453
# Epoch 2/35
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5013 - loss: 1.3138
# Epoch 2: val_accuracy improved from 0.55715 to 0.60101, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 2: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.5154 - loss: 1.2772 - val_accuracy: 0.6010 - val_loss: 1.0445
# Epoch 3/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5360 - loss: 1.2300
# Epoch 3: val_accuracy improved from 0.60101 to 0.62337, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 3: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.5478 - loss: 1.2017 - val_accuracy: 0.6234 - val_loss: 1.0002
# Epoch 4/35
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5559 - loss: 1.1702
# Epoch 4: val_accuracy improved from 0.62337 to 0.64361, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 4: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.5601 - loss: 1.1653 - val_accuracy: 0.6436 - val_loss: 0.9647
# Epoch 5/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5858 - loss: 1.1350
# Epoch 5: val_accuracy improved from 0.64361 to 0.65668, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 5: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.5840 - loss: 1.1263 - val_accuracy: 0.6567 - val_loss: 0.9375
# Epoch 6/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5797 - loss: 1.1123
# Epoch 6: val_accuracy improved from 0.65668 to 0.67060, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 6: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.5855 - loss: 1.1157 - val_accuracy: 0.6706 - val_loss: 0.9134
# Epoch 7/35
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6062 - loss: 1.0854
# Epoch 7: val_accuracy improved from 0.67060 to 0.67398, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 7: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.6060 - loss: 1.0811 - val_accuracy: 0.6740 - val_loss: 0.8999
# Epoch 8/35
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6074 - loss: 1.0812
# Epoch 8: val_accuracy improved from 0.67398 to 0.67735, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 8: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6102 - loss: 1.0725 - val_accuracy: 0.6774 - val_loss: 0.8973
# Epoch 9/35
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6224 - loss: 1.0490
# Epoch 9: val_accuracy improved from 0.67735 to 0.68874, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 9: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6210 - loss: 1.0494 - val_accuracy: 0.6887 - val_loss: 0.8710
# Epoch 10/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6267 - loss: 1.0345
# Epoch 10: val_accuracy did not improve from 0.68874
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.6222 - loss: 1.0410 - val_accuracy: 0.6879 - val_loss: 0.8631
# Epoch 11/35
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6252 - loss: 1.0314
# Epoch 11: val_accuracy improved from 0.68874 to 0.69633, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 11: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.6279 - loss: 1.0335 - val_accuracy: 0.6963 - val_loss: 0.8517
# Epoch 12/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6275 - loss: 1.0342
# Epoch 12: val_accuracy improved from 0.69633 to 0.70013, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 12: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.6371 - loss: 1.0219 - val_accuracy: 0.7001 - val_loss: 0.8449
# Epoch 13/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6371 - loss: 1.0208
# Epoch 13: val_accuracy improved from 0.70013 to 0.70139, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 13: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.6353 - loss: 1.0158 - val_accuracy: 0.7014 - val_loss: 0.8398
# Epoch 14/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6394 - loss: 1.0153
# Epoch 14: val_accuracy improved from 0.70139 to 0.70308, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 14: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.6432 - loss: 1.0041 - val_accuracy: 0.7031 - val_loss: 0.8343
# Epoch 15/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6492 - loss: 0.9828
# Epoch 15: val_accuracy improved from 0.70308 to 0.70772, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 15: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6485 - loss: 0.9926 - val_accuracy: 0.7077 - val_loss: 0.8258
# Epoch 16/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6481 - loss: 0.9947
# Epoch 16: val_accuracy did not improve from 0.70772
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.6461 - loss: 0.9958 - val_accuracy: 0.7060 - val_loss: 0.8243
# Epoch 17/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6435 - loss: 0.9966
# Epoch 17: val_accuracy improved from 0.70772 to 0.71109, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 17: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6472 - loss: 0.9920 - val_accuracy: 0.7111 - val_loss: 0.8188
# Epoch 18/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6517 - loss: 0.9805
# Epoch 18: val_accuracy improved from 0.71109 to 0.71362, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 18: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6523 - loss: 0.9793 - val_accuracy: 0.7136 - val_loss: 0.8162
# Epoch 19/35
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6516 - loss: 0.9961
# Epoch 19: val_accuracy improved from 0.71362 to 0.71573, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 19: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6521 - loss: 0.9818 - val_accuracy: 0.7157 - val_loss: 0.8080
# Epoch 20/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6587 - loss: 0.9622
# Epoch 20: val_accuracy did not improve from 0.71573
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.6592 - loss: 0.9613 - val_accuracy: 0.7149 - val_loss: 0.8039
# Epoch 21/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6554 - loss: 0.9628
# Epoch 21: val_accuracy did not improve from 0.71573
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.6542 - loss: 0.9674 - val_accuracy: 0.7149 - val_loss: 0.8046
# Epoch 22/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6535 - loss: 0.9669
# Epoch 22: val_accuracy did not improve from 0.71573
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6577 - loss: 0.9590 - val_accuracy: 0.7157 - val_loss: 0.7994
# Epoch 23/35
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6580 - loss: 0.9692
# Epoch 23: val_accuracy improved from 0.71573 to 0.71784, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 23: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.6590 - loss: 0.9601 - val_accuracy: 0.7178 - val_loss: 0.7955
# Epoch 24/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6638 - loss: 0.9410
# Epoch 24: val_accuracy did not improve from 0.71784
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6638 - loss: 0.9499 - val_accuracy: 0.7166 - val_loss: 0.7959
# Epoch 25/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6595 - loss: 0.9498
# Epoch 25: val_accuracy did not improve from 0.71784
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6645 - loss: 0.9477 - val_accuracy: 0.7166 - val_loss: 0.7970
# Epoch 26/35
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6677 - loss: 0.9399
# Epoch 26: val_accuracy did not improve from 0.71784
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.6662 - loss: 0.9500 - val_accuracy: 0.7145 - val_loss: 0.7949
# Epoch 27/35
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6605 - loss: 0.9429
# Epoch 27: val_accuracy did not improve from 0.71784
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.6650 - loss: 0.9492 - val_accuracy: 0.7170 - val_loss: 0.7952
# Epoch 28/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6652 - loss: 0.9443
# Epoch 28: val_accuracy did not improve from 0.71784
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6636 - loss: 0.9453 - val_accuracy: 0.7178 - val_loss: 0.7908
# Epoch 29/35
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6649 - loss: 0.9520
# Epoch 29: val_accuracy improved from 0.71784 to 0.71868, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 29: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.6637 - loss: 0.9473 - val_accuracy: 0.7187 - val_loss: 0.7881
# Epoch 30/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6708 - loss: 0.9382
# Epoch 30: val_accuracy did not improve from 0.71868
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6664 - loss: 0.9493 - val_accuracy: 0.7174 - val_loss: 0.7917
# Epoch 31/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6647 - loss: 0.9352
# Epoch 31: val_accuracy improved from 0.71868 to 0.71995, saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
#
# Epoch 31: finished saving model to /home/optimalako/Projet/SAE/artifacts/ethnicity_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6603 - loss: 0.9529 - val_accuracy: 0.7199 - val_loss: 0.7871
# Epoch 32/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6707 - loss: 0.9552
# Epoch 32: val_accuracy did not improve from 0.71995
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6650 - loss: 0.9474 - val_accuracy: 0.7187 - val_loss: 0.7855
# Epoch 33/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6685 - loss: 0.9310
# Epoch 33: val_accuracy did not improve from 0.71995
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6659 - loss: 0.9442 - val_accuracy: 0.7178 - val_loss: 0.7926
# Epoch 34/35
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6606 - loss: 0.9498
# Epoch 34: val_accuracy did not improve from 0.71995
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.6621 - loss: 0.9480 - val_accuracy: 0.7162 - val_loss: 0.7870
# Epoch 35/35
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6662 - loss: 0.9315
# Epoch 35: val_accuracy did not improve from 0.71995
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6676 - loss: 0.9395 - val_accuracy: 0.7195 - val_loss: 0.7880
# Restoring model weights from the end of the best epoch: 31.

# %% [markdown]
# ## 11. Visualisation de l'Entraînement

# %%
def plot_training_history(warmup_hist, finetune_hist):
    """Visualise l'historique d'entraînement."""
    combined_acc = warmup_hist.history["accuracy"] + finetune_hist.history["accuracy"]
    combined_val_acc = (
        warmup_hist.history["val_accuracy"] + finetune_hist.history["val_accuracy"]
    )
    combined_loss = warmup_hist.history["loss"] + finetune_hist.history["loss"]
    combined_val_loss = (
        warmup_hist.history["val_loss"] + finetune_hist.history["val_loss"]
    )

    epochs = range(1, len(combined_acc) + 1)
    warmup_end = len(warmup_hist.history["accuracy"])

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Accuracy
    axes[0].plot(epochs, combined_acc, "b-", label="Train Accuracy", linewidth=2)
    axes[0].plot(epochs, combined_val_acc, "r-", label="Val Accuracy", linewidth=2)
    axes[0].axvline(
        x=warmup_end, color="gray", linestyle="--", label="Début Fine-tuning"
    )
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Accuracy")
    axes[0].set_title("Accuracy")
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    # Loss
    axes[1].plot(epochs, combined_loss, "b-", label="Train Loss", linewidth=2)
    axes[1].plot(epochs, combined_val_loss, "r-", label="Val Loss", linewidth=2)
    axes[1].axvline(
        x=warmup_end, color="gray", linestyle="--", label="Début Fine-tuning"
    )
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Loss")
    axes[1].set_title("Cross-Entropy Loss")
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(ARTIFACTS_DIR / "ethnicity_training_history.png", dpi=150)
    plt.show()

    best_val_acc = max(combined_val_acc)
    best_epoch = combined_val_acc.index(best_val_acc) + 1
    print(f"\nMeilleure Val Accuracy: {best_val_acc:.4f} (epoch {best_epoch})")


plot_training_history(warmup_history, finetune_history)
# Out:
# Meilleure Val Accuracy: 0.7199 (epoch 46)

# %% [markdown]
# ## 12. Évaluation sur le Test Set

# %%
# Charger le meilleur modèle
best_model = keras.models.load_model(ARTIFACTS_DIR / "ethnicity_model_best.keras")

# Évaluation
test_results = best_model.evaluate(test_ds, verbose=1)
print(f"\nRésultats sur le test set:")
print(f"  - Loss: {test_results[0]:.4f}")
print(f"  - Accuracy: {test_results[1]:.4f} ({test_results[1]*100:.2f}%)")
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.7212 - loss: 0.7851
#
# Résultats sur le test set:
#   - Loss: 0.7851
#   - Accuracy: 0.7212 (72.12%)

# %%
# Prédictions détaillées
y_pred_proba = best_model.predict(test_ds, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = y_test

# Métriques
accuracy = np.mean(y_pred == y_true)
f1_macro = f1_score(y_true, y_pred, average="macro")
f1_weighted = f1_score(y_true, y_pred, average="weighted")

print(f"\nMétriques détaillées:")
print(f"  - Accuracy: {accuracy:.4f}")
print(f"  - F1 Score (macro): {f1_macro:.4f}")
print(f"  - F1 Score (weighted): {f1_weighted:.4f}")
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step
#
# Métriques détaillées:
#   - Accuracy: 0.7212
#   - F1 Score (macro): 0.6454
#   - F1 Score (weighted): 0.7268

# %%
# Rapport de classification détaillé
print("\nRapport de classification:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES))
# Out:
# Rapport de classification:
#               precision    recall  f1-score   support
#
#        White       0.85      0.79      0.82      1008
#        Black       0.79      0.81      0.80       453
#        Asian       0.63      0.82      0.72       343
#       Indian       0.74      0.51      0.60       398
#       Others       0.24      0.36      0.29       169
#
#     accuracy                           0.72      2371
#    macro avg       0.65      0.66      0.65      2371
# weighted avg       0.75      0.72      0.73      2371

# %% [markdown]
# ## 13. Matrice de Confusion

# %%
# Matrice de confusion
cm = confusion_matrix(y_true, y_pred)
cm_normalized = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Counts
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES,
    ax=axes[0],
)
axes[0].set_xlabel("Prédit")
axes[0].set_ylabel("Réel")
axes[0].set_title("Matrice de Confusion (counts)")

# Normalized
sns.heatmap(
    cm_normalized,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES,
    ax=axes[1],
)
axes[1].set_xlabel("Prédit")
axes[1].set_ylabel("Réel")
axes[1].set_title("Matrice de Confusion (normalisée)")

plt.tight_layout()
plt.savefig(ARTIFACTS_DIR / "ethnicity_confusion_matrix.png", dpi=150)
plt.show()

# %% [markdown]
# ## 14. Analyse des Erreurs par Classe

# %%
# Analyse par classe
results_df = pd.DataFrame(
    {
        "true": y_true,
        "predicted": y_pred,
        "true_name": [ETHNICITY_MAP[y] for y in y_true],
        "predicted_name": [ETHNICITY_MAP[y] for y in y_pred],
        "correct": y_pred == y_true,
        "confidence": y_pred_proba.max(axis=1),
    }
)

# Accuracy et confiance par classe
class_analysis = (
    results_df.groupby("true_name")
    .agg({"correct": ["mean", "sum", "count"], "confidence": "mean"})
    .round(3)
)
class_analysis.columns = ["Accuracy", "Correct", "Total", "Avg Confidence"]
print("Analyse par classe:")
display(class_analysis)
# Out:
# Analyse par classe:
#            Accuracy  Correct  Total  Avg Confidence
# true_name
# Asian         0.822      282    343           0.731
# Black         0.812      368    453           0.736
# Indian        0.505      201    398           0.571
# Others        0.361       61    169           0.543
# White         0.792      798   1008           0.700

# %%
# Distribution de la confiance pour les prédictions correctes vs incorrectes
fig, ax = plt.subplots(figsize=(10, 5))

correct_conf = results_df[results_df["correct"]]["confidence"]
incorrect_conf = results_df[~results_df["correct"]]["confidence"]

ax.hist(
    correct_conf,
    bins=30,
    alpha=0.7,
    label=f"Correct (n={len(correct_conf)})",
    color="green",
)
ax.hist(
    incorrect_conf,
    bins=30,
    alpha=0.7,
    label=f"Incorrect (n={len(incorrect_conf)})",
    color="red",
)
ax.set_xlabel("Confiance")
ax.set_ylabel("Fréquence")
ax.set_title("Distribution de la confiance")
ax.legend()

plt.tight_layout()
plt.show()

print(f"Confiance moyenne (correct): {correct_conf.mean():.3f}")
print(f"Confiance moyenne (incorrect): {incorrect_conf.mean():.3f}")
# Out:
# Confiance moyenne (correct): 0.738
# Confiance moyenne (incorrect): 0.526

# %% [markdown]
# ## 15. Exemples de Prédictions

# %%
def show_predictions(model, filepaths, true_labels, n_samples=12):
    """Affiche une grille de prédictions."""
    indices = np.random.choice(len(filepaths), n_samples, replace=False)

    fig, axes = plt.subplots(3, 4, figsize=(16, 12))

    for idx, ax in zip(indices, axes.flat):
        img = Image.open(filepaths[idx]).convert("RGB").resize((IMG_SIZE, IMG_SIZE))
        img_array = np.array(img, dtype=np.float32)  # En [0, 255]

        proba = model.predict(img_array[np.newaxis, ...], verbose=0)[0]
        pred = np.argmax(proba)
        conf = proba[pred]
        true = true_labels[idx]

        # Afficher l'image originale (normalisée en [0, 1])
        ax.imshow(img_array / 255.0)
        color = "green" if pred == true else "red"
        ax.set_title(
            f"Réel: {ETHNICITY_MAP[true]}\nPrédit: {ETHNICITY_MAP[pred]} ({conf:.2f})",
            color=color,
            fontsize=10,
        )
        ax.axis("off")

    plt.suptitle(
        "Exemples de prédictions (vert: correct, rouge: incorrect)", fontsize=14
    )
    plt.tight_layout()
    plt.savefig(ARTIFACTS_DIR / "ethnicity_predictions_examples.png", dpi=150)
    plt.show()


show_predictions(best_model, X_test, y_test)
# Out:
# 2026-01-18 12:36:09.024765: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:36:09.111224: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:36:09.198525: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:36:09.285453: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:36:09.372203: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:36:09.459142: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:36:09.882389: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:36:09.968482: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.

# %% [markdown]
# ## 16. Sauvegarde du Modèle Final

# %%
# Sauvegarder le modèle final
final_model_path = ARTIFACTS_DIR / "ethnicity_model_final.keras"
best_model.save(final_model_path)
print(f"Modèle sauvegardé: {final_model_path}")

# Sauvegarder les infos du modèle et les classes
import json

model_info = {
    "img_size": IMG_SIZE,
    "classes": CLASS_NAMES,
    "class_map": {str(k): v for k, v in ETHNICITY_MAP.items()},
    "input_range": [0, 255],  # Plage des valeurs d'entrée attendues
}

with open(ARTIFACTS_DIR / "ethnicity_model_info.json", "w") as f:
    json.dump(model_info, f, indent=2)
print(f"Infos du modèle sauvegardées")
# Out:
# Modèle sauvegardé: /home/optimalako/Projet/SAE/artifacts/ethnicity_model_final.keras
# Infos du modèle sauvegardées

# %%
# Conversion en TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

tflite_path = ARTIFACTS_DIR / "ethnicity_model.tflite"
with open(tflite_path, "wb") as f:
    f.write(tflite_model)

print(f"Modèle TFLite sauvegardé: {tflite_path}")
print(f"Taille: {tflite_path.stat().st_size / 1024 / 1024:.2f} MB")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpd9fi0_h9/assets
# INFO:tensorflow:Assets written to: /tmp/tmpd9fi0_h9/assets
# Saved artifact at '/tmp/tmpd9fi0_h9'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_image')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   128859249214288: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   128859249213904: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   128857354643664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354645968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354639440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354646736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354647312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354647504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354644816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354646928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354647888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354648464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354646160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354648848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354646352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354646544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354647696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354649232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354649424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354648080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354649040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354648272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074992336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074992528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354647120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857354648656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074991184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074991376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074991760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074993104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074993680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074992912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074994064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074992144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074993488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074993872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074992720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074994640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074993296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074995408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074991952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074994832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074995216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074995792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074996368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074995600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074995024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074996176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074996752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074997328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074996560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074997712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074994448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074997136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074997520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074995984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074998288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074996944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074999056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074999248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074998672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074997904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074999632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075000208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074998864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074998480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075000016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075000592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075001168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075000400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075001552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074999440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075000976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075001360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074999824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075002128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075000784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075002896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857074998096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075002320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075002704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075003280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075003856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075003088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075002512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075003664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075004240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075004816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075004048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075005200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075001936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075004624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075005008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075003472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075005776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075004432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075006544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075006736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075005392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075005968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075005584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075001744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075007120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075006352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075006160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075007312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128857075006928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252474128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252475472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252475280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252474704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252474320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252474512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252476048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252474896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252476816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252475088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252476240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252476624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252477200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252477776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252477008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252476432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252477584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252478160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252478736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252477968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252479120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252475856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252478544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252478928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252477392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252479696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252478352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252480464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252480656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252480080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252479312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252481040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252481616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252480272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252479888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252481424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252482000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252482576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252481808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252482960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252480848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252482384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252482768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252481232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252483536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252482192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252484304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252484496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252483920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252483152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252484880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252485456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252484112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252483728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252485264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252485840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252486416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252485648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252486800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252484688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252486224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252486608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252485072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252487376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252486032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252488144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252483344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252487568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252487952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252488528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252489104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252488336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252487760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252488912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252489488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252490064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252489296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252489680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252487184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252488720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252489872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251294864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251294480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252475664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859252486992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251296016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251294672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251295440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251296400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251296976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251295632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251295824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251296784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251297360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251297936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251297168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251298320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251296208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251297744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251298128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251296592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251298896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251297552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251299664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251299856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251299280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251298512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251300240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251300816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251299472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251299088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251300624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251301200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251301776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251301008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251302160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251300048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251301584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251301968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251300432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251302736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251301392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251303504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251298704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251302928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251303312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251303888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251304464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251303696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251303120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251304272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251304848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251305424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251304656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251305808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251302544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251305232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251305616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251304080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251306384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251305040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251307152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251307344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251306768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251306000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251307728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251308304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251306960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251306576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251308112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251308688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251309264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251308496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251309648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251307536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251309456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251307920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251306192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251310224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251310032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251309072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251310416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250148560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250148752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251308880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859251302352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250147408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250147600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250147984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250149328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250149904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250149136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250150288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250148368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250149712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250150096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250148944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250150864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250149520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250151632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250151824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250151248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250150480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250152208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250152784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250151440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250151056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250152592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250153168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250153744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250152976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250154128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250152016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250153552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250153936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250152400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250154704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250153360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250155472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250150672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250154896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250155280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250155856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250156432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250155088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250156240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250154512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250157392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250157200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250147792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250157776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250157584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250156624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250158736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250158544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250157968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250159120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   128859250158928: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modèle TFLite sauvegardé: /home/optimalako/Projet/SAE/artifacts/ethnicity_model.tflite
# Taille: 5.01 MB
# W0000 00:00:1768736180.398630   31949 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1768736180.398648   31949 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1768736180.500988   31949 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled

# %% [markdown]
# ## 17. Résumé des Performances

# %%
print("=" * 60)
print("RÉSUMÉ DU MODÈLE DE CLASSIFICATION D'ETHNICITÉ")
print("=" * 60)
print(f"\nArchitecture: EfficientNetB0 + Dense Head")
print(f"Input size: {IMG_SIZE}x{IMG_SIZE}x3")
print(f"Classes: {CLASS_NAMES}")
print(
    f"Dataset: {len(df)} images (train: {len(X_train)}, val: {len(X_val)}, test: {len(X_test)})"
)
print(f"\nPerformances sur le test set:")
print(f"  - Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")
print(f"  - F1 Score (macro): {f1_macro:.4f}")
print(f"  - F1 Score (weighted): {f1_weighted:.4f}")
print(f"\nFichiers sauvegardés:")
print(f"  - {final_model_path}")
print(f"  - {tflite_path}")
print("=" * 60)
# Out:
# ============================================================
# RÉSUMÉ DU MODÈLE DE CLASSIFICATION D'ETHNICITÉ
# ============================================================
#
# Architecture: EfficientNetB0 + Dense Head
# Input size: 128x128x3
# Classes: ['White', 'Black', 'Asian', 'Indian', 'Others']
# Dataset: 23705 images (train: 18963, val: 2371, test: 2371)
#
# Performances sur le test set:
#   - Accuracy: 0.7212 (72.12%)
#   - F1 Score (macro): 0.6454
#   - F1 Score (weighted): 0.7268
#
# Fichiers sauvegardés:
#   - /home/optimalako/Projet/SAE/artifacts/ethnicity_model_final.keras
#   - /home/optimalako/Projet/SAE/artifacts/ethnicity_model.tflite
# ============================================================
