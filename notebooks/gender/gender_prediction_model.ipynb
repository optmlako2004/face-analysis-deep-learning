# %% [markdown]
# # Modèle Spécialisé - Prédiction de Genre
#
# Ce notebook implémente un modèle de deep learning spécialisé dans la classification du genre à partir de photos de visages.
#
# **Architecture:** Transfer Learning avec EfficientNetB0
# **Tâche:** Classification binaire
# **Dataset:** UTKFace (23,708 images)
#
# **Classes:**
#
# - 0: Male (Homme)
# - 1: Female (Femme)

# %% [markdown]
# ## 1. Configuration et Imports

# %%
import os, sys, pathlib
ROOT = pathlib.Path.cwd()
if not (ROOT / 'config.py').exists():
    for parent in ROOT.parents:
        if (parent / 'config.py').exists():
            ROOT = parent
            break
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from config import (
    BASE_DIR, DATA_DIR, RAW_DIR, IMAGES_DIR, ARTIFACTS_DIR,
    NOTEBOOKS_DIR, ANDROID_ASSETS_DIR, TESTS_DIR, DIAGNOSTICS_DIR,
    ensure_kaggle_credentials, ensure_kaggle_dataset, describe_config,
    artifacts_for,
 )

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, callbacks
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import CosineDecay

import numpy as np
import matplotlib.pyplot as plt
import json
import time
from PIL import Image
from pathlib import Path
import pandas as pd
import seaborn as sns
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_curve,
    auc,
    precision_recall_curve,
)
from sklearn.utils.class_weight import compute_class_weight

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU disponible: {tf.config.list_physical_devices('GPU')}")

print('Working dir set to', ROOT)
print(describe_config())
# Out:
# 2026-03-27 22:33:41.924573: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-27 22:33:41.999999: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-27 22:33:42.359715: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-27 22:33:42.359880: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-27 22:33:42.438688: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-27 22:33:42.592992: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-27 22:33:42.595087: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-27 22:33:43.585524: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TensorFlow version: 2.15.0
# GPU disponible: []
# Working dir set to /home/carld/face-analysis-deep-learning
# {'BASE_DIR': '/home/carld/face-analysis-deep-learning', 'DATA_DIR': '/home/carld/face-analysis-deep-learning/data', 'RAW_DIR': '/home/carld/face-analysis-deep-learning/data/raw', 'IMAGES_DIR': '/home/carld/face-analysis-deep-learning/data/UTKFace', 'ARTIFACTS_DIR': '/home/carld/face-analysis-deep-learning/artifacts', 'ANDROID_ASSETS_DIR': '/home/carld/face-analysis-deep-learning/FacePredictor/app/src/main/assets', 'TESTS_DIR': '/home/carld/face-analysis-deep-learning/tests', 'DIAGNOSTICS_DIR': '/home/carld/face-analysis-deep-learning/diagnostics', 'DATASET_ID': 'jangedoo/utkface-new'}
# 2026-03-27 22:33:45.818346: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-03-27 22:33:45.818678: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ## 2. Constantes et Hyperparamètres

# %%
# Chemins
DATA_DIR = IMAGES_DIR
DATASET_PATH = IMAGES_DIR
OUTPUT_DIR = artifacts_for("gender", "gender_prediction_model")
ARTIFACTS_DIR = OUTPUT_DIR

# Classes de genre
GENDER_MAP = {0: "Male", 1: "Female"}
NUM_CLASSES = 2
CLASS_NAMES = list(GENDER_MAP.values())

# Seed global pour reproductibilité
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Hyperparamètres
IMG_SIZE = 128
BATCH_SIZE = 32
WARMUP_EPOCHS = 12
FINETUNE_EPOCHS = 30
INITIAL_LR = 1e-3
FINETUNE_LR = 1e-5

# Validation
VAL_SPLIT = 0.1
TEST_SPLIT = 0.1

print(f"Dataset: {DATASET_PATH}")
print(f"Output: {OUTPUT_DIR}")
print(f"Configuration:")
print(f"  - Classes: {CLASS_NAMES}")
print(f"  - Image size: {IMG_SIZE}x{IMG_SIZE}")
print(f"  - Batch size: {BATCH_SIZE}")
# Out:
# Dataset: /home/carld/face-analysis-deep-learning/data/UTKFace
# Output: /home/carld/face-analysis-deep-learning/artifacts/gender/gender_prediction_model
# Configuration:
#   - Classes: ['Male', 'Female']
#   - Image size: 128x128
#   - Batch size: 32

# %% [markdown]
# ## 3. Chargement des Données

# %%
def parse_utkface_filename(filepath: Path) -> dict | None:
    try:
        name = filepath.name.split(".")[0]
        parts = name.split("_")
        if len(parts) < 2:
            return None

        gender = int(parts[1]) if parts[1].isdigit() else -1

        # Filtrer les genres invalides (garder uniquement 0 et 1)
        if gender not in [0, 1]:
            return None

        return {
            "filepath": str(filepath),
            "gender": gender,
            "gender_name": GENDER_MAP.get(gender, "Unknown"),
        }
    except Exception:
        return None


# Charger toutes les images
image_paths = list(DATA_DIR.glob("*.jpg*"))
print(f"Images trouvées: {len(image_paths)}")

# Parser les métadonnées
from tqdm import tqdm
records = []
for path in tqdm(image_paths, desc="Parsing des fichiers"):
    record = parse_utkface_filename(path)
    if record:
        records.append(record)

df = pd.DataFrame(records)
print(f"\nImages valides: {len(df)}")
# Out:
# Images trouvées: 23708
# Parsing des fichiers: 100%|██████████| 23708/23708 [00:00<00:00, 741807.54it/s]
# Images valides: 23708

# %%
# Distribution des classes
print("Distribution des genres:")
class_counts = df["gender_name"].value_counts()
print(class_counts)

# Visualisation
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Bar plot
colors = ["#4C72B0", "#DD8452"]
class_counts_sorted = df["gender"].value_counts().sort_index()
axes[0].bar(
    [GENDER_MAP[i] for i in class_counts_sorted.index],
    class_counts_sorted.values,
    color=colors,
    edgecolor="black",
)
axes[0].set_xlabel("Genre")
axes[0].set_ylabel("Nombre d'images")
axes[0].set_title("Distribution des genres")
for i, v in enumerate(class_counts_sorted.values):
    axes[0].text(i, v + 100, str(v), ha="center", fontsize=12)

# Pie chart
axes[1].pie(
    class_counts_sorted.values,
    labels=[GENDER_MAP[i] for i in class_counts_sorted.index],
    autopct="%1.1f%%",
    colors=colors,
    startangle=90,
    explode=(0.02, 0.02),
)
axes[1].set_title("Répartition des genres")

plt.tight_layout()
plt.show()

# Ratio
ratio = class_counts.max() / class_counts.min()
print(f"\nRatio hommes/femmes: {ratio:.2f}")
# Out:
# Distribution des genres:
# gender_name
# Male      12391
# Female    11317
# Name: count, dtype: int64
# Ratio hommes/femmes: 1.09

# %% [markdown]
# ## 4. Split Train/Validation/Test (Stratifié)

# %%
# Split stratifié
X = df["filepath"].values
y = df["gender"].values

# Premier split: train+val vs test
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=TEST_SPLIT, stratify=y, random_state=SEED
)

# Deuxième split: train vs val
X_train, X_val, y_train, y_val = train_test_split(
    X_temp,
    y_temp,
    test_size=VAL_SPLIT / (1 - TEST_SPLIT),
    stratify=y_temp,
    random_state=SEED,
)

print(f"Split des données:")
print(f"  - Train: {len(X_train)} ({len(X_train)/len(X)*100:.1f}%)")
print(f"  - Validation: {len(X_val)} ({len(X_val)/len(X)*100:.1f}%)")
print(f"  - Test: {len(X_test)} ({len(X_test)/len(X)*100:.1f}%)")

# Vérifier la stratification
print(f"\nDistribution dans le train set:")
for g in [0, 1]:
    count = (y_train == g).sum()
    print(f"  - {GENDER_MAP[g]}: {count} ({count/len(y_train)*100:.1f}%)")
# Out:
# Split des données:
#   - Train: 18966 (80.0%)
#   - Validation: 2371 (10.0%)
#   - Test: 2371 (10.0%)
#
# Distribution dans le train set:
#   - Male: 9913 (52.3%)
#   - Female: 9053 (47.7%)

# %% [markdown]
# ## 5. Calcul des Poids de Classes

# %%
# Poids de classes pour équilibrer
class_weights_array = compute_class_weight(
    class_weight="balanced", classes=np.unique(y_train), y=y_train
)
class_weights = dict(enumerate(class_weights_array))

print("Poids des classes:")
for cls, weight in class_weights.items():
    print(f"  - {GENDER_MAP[cls]}: {weight:.3f}")
# Out:
# Poids des classes:
#   - Male: 0.957
#   - Female: 1.047

# %% [markdown]
# ## 7. Pipeline de Données avec Data Augmentation

# %%
# Data augmentation
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.08),  # ±8% (moins que pour l'âge/ethnicité)
        layers.RandomZoom(0.1),
        layers.RandomTranslation(0.08, 0.08),
        layers.RandomBrightness(0.15),
        layers.RandomContrast(0.15),
    ],
    name="data_augmentation",
)


def load_and_preprocess(filepath, label):
    """Charge et prétraite une image (sans normalisation pour permettre l'augmentation)."""
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32)
    return img, label


def create_dataset(filepaths, labels, batch_size, shuffle=True, augment=False):
    """Crée un tf.data.Dataset."""
    ds = tf.data.Dataset.from_tensor_slices((filepaths, labels))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(filepaths), seed=SEED)

    ds = ds.map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size)

    if augment:
        ds = ds.map(
            lambda x, y: (data_augmentation(x, training=True), y),
            num_parallel_calls=tf.data.AUTOTUNE,
        )

    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds


# Créer les datasets
train_ds = create_dataset(X_train, y_train, BATCH_SIZE, shuffle=True, augment=True)
val_ds = create_dataset(X_val, y_val, BATCH_SIZE, shuffle=False, augment=False)
test_ds = create_dataset(X_test, y_test, BATCH_SIZE, shuffle=False, augment=False)

print("Datasets créés avec succès!")
# Out:
# Datasets créés avec succès!

# %%
# Visualiser quelques exemples
fig, axes = plt.subplots(2, 4, figsize=(16, 8))

for images, labels in train_ds.take(1):
    for i, ax in enumerate(axes.flat):
        if i < len(images):
            # Images sont en [0, 255], normaliser pour affichage
            img = images[i].numpy() / 255.0
            img = np.clip(img, 0, 1)
            ax.imshow(img)
            ax.set_title(f"{GENDER_MAP[labels[i].numpy()]}", fontsize=12)
            ax.axis("off")

plt.suptitle("Exemples d'images par genre", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Construction du Modèle

# %%
def build_gender_model(img_size: int, trainable_backbone: bool = False) -> Model:
    """Construit le modèle de classification de genre avec EfficientNetB0."""

    inputs = layers.Input(shape=(img_size, img_size, 3), name="input_image")

    # Backbone EfficientNetB0
    backbone = EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_shape=(img_size, img_size, 3),
        pooling=None,
    )
    backbone.trainable = trainable_backbone

    x = backbone(inputs)

    # Double pooling (GAP + GMP) pour capturer plus d'informations
    gap = layers.GlobalAveragePooling2D(name="gap")(x)
    gmp = layers.GlobalMaxPooling2D(name="gmp")(x)
    x = layers.Concatenate(name="concat_pool")([gap, gmp])

    # Head de classification binaire
    x = layers.Dense(128, activation="relu", name="dense_1")(x)
    x = layers.BatchNormalization(name="bn_1")(x)
    x = layers.Dropout(0.4, name="dropout_1")(x)

    x = layers.Dense(32, activation="relu", name="dense_2")(x)
    x = layers.BatchNormalization(name="bn_2")(x)
    x = layers.Dropout(0.3, name="dropout_2")(x)

    # Output binaire (sigmoid)
    outputs = layers.Dense(1, activation="sigmoid", name="gender_output")(x)

    model = Model(inputs, outputs, name="GenderModel_EfficientNetB0")
    return model, backbone


# Construire le modèlemodel.summary()
model, backbone = build_gender_model(IMG_SIZE, trainable_backbone=False)

# %% [markdown]
# ## 9. Phase 1: Warmup (Backbone Gelé)

# %%
steps_per_epoch = len(X_train) // BATCH_SIZE
total_warmup_steps = steps_per_epoch * WARMUP_EPOCHS

warmup_lr_schedule = CosineDecay(
    initial_learning_rate=INITIAL_LR, decay_steps=total_warmup_steps, alpha=0.1
)

model.compile(
    optimizer=Adam(learning_rate=warmup_lr_schedule),
    loss="binary_crossentropy",
    metrics=["accuracy", keras.metrics.AUC(name="auc")],
)

warmup_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=8,
        restore_best_weights=True,
        mode="max",
        verbose=1,
    ),
    callbacks.ModelCheckpoint(
        filepath=str(ARTIFACTS_DIR / "gender_warmup_best.keras"),
        monitor="val_accuracy",
        save_best_only=True,
        mode="max",
        verbose=1,
    ),
    # Note: Pas de ReduceLROnPlateau car CosineDecay gère déjà la décroissance du LR
]

print(f"Phase 1: Warmup ({WARMUP_EPOCHS} epochs, backbone gelé)")
print(
    f"Paramètres entraînables: {sum([tf.reduce_prod(w.shape).numpy() for w in model.trainable_weights]):,}"
)
# Out:
# Phase 1: Warmup (12 epochs, backbone gelé)
# Paramètres entraînables: 332,289

# %%
# Entraînement Phase 1
warmup_history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=WARMUP_EPOCHS,
    callbacks=warmup_callbacks,
    class_weight=class_weights,
    verbose=1,
)
# Out:
# Epoch 1/12
#  12/593 [..............................] - ETA: 1:03 - loss: 0.7486 - accuracy: 0.6406 - auc: 0.6832
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Entraînement Phase 1
# ----> 2 warmup_history = model.fit(
#       3     train_ds,
#       4     validation_data=val_ds,
#       5     epochs=WARMUP_EPOCHS,
#       6     callbacks=warmup_callbacks,
#       7     class_weight=class_weights,
#       8     verbose=1,
#       9 )
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/projet_py/.venv/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 10. Phase 2: Fine-tuning

# %%
# Dégeler les dernières couches du backbone
backbone.trainable = True

freeze_until = len(backbone.layers) - 40  # Un peu moins que pour les autres modèles
for layer in backbone.layers[:freeze_until]:
    layer.trainable = False

trainable_count = sum(
    [tf.reduce_prod(w.shape).numpy() for w in model.trainable_weights]
)
print(f"Phase 2: Fine-tuning ({FINETUNE_EPOCHS} epochs)")
print(f"Couches dégelées: {len(backbone.layers) - freeze_until}/{len(backbone.layers)}")
print(f"Paramètres entraînables: {trainable_count:,}")
# Out:
# Phase 2: Fine-tuning (30 epochs)
# Couches dégelées: 40/238
# Paramètres entraînables: 2,382,993

# %%
total_finetune_steps = steps_per_epoch * FINETUNE_EPOCHS

finetune_lr_schedule = CosineDecay(
    initial_learning_rate=FINETUNE_LR, decay_steps=total_finetune_steps, alpha=0.01
)

model.compile(
    optimizer=Adam(learning_rate=finetune_lr_schedule),
    loss="binary_crossentropy",
    metrics=["accuracy", keras.metrics.AUC(name="auc")],
)

finetune_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=12,
        restore_best_weights=True,
        mode="max",
        verbose=1,
    ),
    callbacks.ModelCheckpoint(
        filepath=str(ARTIFACTS_DIR / "gender_model_best.keras"),
        monitor="val_accuracy",
        save_best_only=True,
        mode="max",
        verbose=1,
    ),
    # Note: Pas de ReduceLROnPlateau car CosineDecay gère déjà la décroissance du LR
]

# %%
# Entraînement Phase 2
finetune_history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=FINETUNE_EPOCHS,
    callbacks=finetune_callbacks,
    class_weight=class_weights,
    verbose=1,
)
# Out:
# Epoch 1/30
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7338 - auc: 0.8082 - loss: 0.5564
# 2026-01-18 12:48:49.951355: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:48:50.038910: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7339 - auc: 0.8084 - loss: 0.5561
# Epoch 1: val_accuracy improved from None to 0.82244, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 1: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 45s 48ms/step - accuracy: 0.7589 - auc: 0.8359 - loss: 0.5133 - val_accuracy: 0.8224 - val_auc: 0.9025 - val_loss: 0.3955
# Epoch 2/30
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7870 - auc: 0.8692 - loss: 0.4560
# Epoch 2: val_accuracy improved from 0.82244 to 0.83762, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 2: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.7916 - auc: 0.8758 - loss: 0.4445 - val_accuracy: 0.8376 - val_auc: 0.9195 - val_loss: 0.3614
# Epoch 3/30
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8084 - auc: 0.8930 - loss: 0.4132
# Epoch 3: val_accuracy improved from 0.83762 to 0.84437, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 3: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.8095 - auc: 0.8936 - loss: 0.4126 - val_accuracy: 0.8444 - val_auc: 0.9291 - val_loss: 0.3423
# Epoch 4/30
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8234 - auc: 0.9048 - loss: 0.3929
# Epoch 4: val_accuracy improved from 0.84437 to 0.85407, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 4: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8239 - auc: 0.9063 - loss: 0.3892 - val_accuracy: 0.8541 - val_auc: 0.9359 - val_loss: 0.3293
# Epoch 5/30
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8276 - auc: 0.9104 - loss: 0.3821
# Epoch 5: val_accuracy improved from 0.85407 to 0.86251, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 5: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8316 - auc: 0.9143 - loss: 0.3733 - val_accuracy: 0.8625 - val_auc: 0.9407 - val_loss: 0.3153
# Epoch 6/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8298 - auc: 0.9153 - loss: 0.3697
# Epoch 6: val_accuracy improved from 0.86251 to 0.86799, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 6: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.8367 - auc: 0.9181 - loss: 0.3645 - val_accuracy: 0.8680 - val_auc: 0.9448 - val_loss: 0.3052
# Epoch 7/30
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8366 - auc: 0.9202 - loss: 0.3596
# Epoch 7: val_accuracy improved from 0.86799 to 0.86925, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 7: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.8418 - auc: 0.9227 - loss: 0.3551 - val_accuracy: 0.8693 - val_auc: 0.9475 - val_loss: 0.2997
# Epoch 8/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8437 - auc: 0.9260 - loss: 0.3472
# Epoch 8: val_accuracy improved from 0.86925 to 0.87685, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 8: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.8441 - auc: 0.9255 - loss: 0.3487 - val_accuracy: 0.8768 - val_auc: 0.9503 - val_loss: 0.2898
# Epoch 9/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8489 - auc: 0.9268 - loss: 0.3459
# Epoch 9: val_accuracy did not improve from 0.87685
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.8506 - auc: 0.9290 - loss: 0.3410 - val_accuracy: 0.8747 - val_auc: 0.9522 - val_loss: 0.2842
# Epoch 10/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8543 - auc: 0.9335 - loss: 0.3302
# Epoch 10: val_accuracy improved from 0.87685 to 0.87853, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 10: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.8516 - auc: 0.9324 - loss: 0.3326 - val_accuracy: 0.8785 - val_auc: 0.9532 - val_loss: 0.2809
# Epoch 11/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8578 - auc: 0.9355 - loss: 0.3268
# Epoch 11: val_accuracy did not improve from 0.87853
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8581 - auc: 0.9354 - loss: 0.3266 - val_accuracy: 0.8781 - val_auc: 0.9544 - val_loss: 0.2793
# Epoch 12/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8653 - auc: 0.9389 - loss: 0.3194
# Epoch 12: val_accuracy improved from 0.87853 to 0.88444, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 12: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - accuracy: 0.8630 - auc: 0.9383 - loss: 0.3191 - val_accuracy: 0.8844 - val_auc: 0.9557 - val_loss: 0.2732
# Epoch 13/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8612 - auc: 0.9392 - loss: 0.3170
# Epoch 13: val_accuracy did not improve from 0.88444
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8594 - auc: 0.9378 - loss: 0.3204 - val_accuracy: 0.8802 - val_auc: 0.9564 - val_loss: 0.2715
# Epoch 14/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8656 - auc: 0.9405 - loss: 0.3137
# Epoch 14: val_accuracy did not improve from 0.88444
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8610 - auc: 0.9379 - loss: 0.3192 - val_accuracy: 0.8827 - val_auc: 0.9574 - val_loss: 0.2683
# Epoch 15/30
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8592 - auc: 0.9394 - loss: 0.3157
# Epoch 15: val_accuracy did not improve from 0.88444
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.8619 - auc: 0.9404 - loss: 0.3131 - val_accuracy: 0.8823 - val_auc: 0.9578 - val_loss: 0.2679
# Epoch 16/30
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8681 - auc: 0.9416 - loss: 0.3113
# Epoch 16: val_accuracy did not improve from 0.88444
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.8667 - auc: 0.9414 - loss: 0.3108 - val_accuracy: 0.8827 - val_auc: 0.9583 - val_loss: 0.2667
# Epoch 17/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8648 - auc: 0.9409 - loss: 0.3130
# Epoch 17: val_accuracy improved from 0.88444 to 0.88528, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 17: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.8661 - auc: 0.9414 - loss: 0.3109 - val_accuracy: 0.8853 - val_auc: 0.9590 - val_loss: 0.2626
# Epoch 18/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8591 - auc: 0.9385 - loss: 0.3179
# Epoch 18: val_accuracy did not improve from 0.88528
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.8673 - auc: 0.9420 - loss: 0.3092 - val_accuracy: 0.8853 - val_auc: 0.9595 - val_loss: 0.2613
# Epoch 19/30
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8670 - auc: 0.9420 - loss: 0.3089
# Epoch 19: val_accuracy did not improve from 0.88528
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.8679 - auc: 0.9437 - loss: 0.3045 - val_accuracy: 0.8840 - val_auc: 0.9599 - val_loss: 0.2625
# Epoch 20/30
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8678 - auc: 0.9420 - loss: 0.3099
# Epoch 20: val_accuracy did not improve from 0.88528
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.8657 - auc: 0.9426 - loss: 0.3074 - val_accuracy: 0.8840 - val_auc: 0.9600 - val_loss: 0.2616
# Epoch 21/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8705 - auc: 0.9483 - loss: 0.2926
# Epoch 21: val_accuracy improved from 0.88528 to 0.89076, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 21: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.8707 - auc: 0.9454 - loss: 0.3005 - val_accuracy: 0.8908 - val_auc: 0.9605 - val_loss: 0.2580
# Epoch 22/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8732 - auc: 0.9479 - loss: 0.2943
# Epoch 22: val_accuracy did not improve from 0.89076
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.8719 - auc: 0.9467 - loss: 0.2972 - val_accuracy: 0.8853 - val_auc: 0.9603 - val_loss: 0.2618
# Epoch 23/30
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8676 - auc: 0.9453 - loss: 0.3013
# Epoch 23: val_accuracy did not improve from 0.89076
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8727 - auc: 0.9472 - loss: 0.2959 - val_accuracy: 0.8891 - val_auc: 0.9606 - val_loss: 0.2583
# Epoch 24/30
# 590/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8742 - auc: 0.9470 - loss: 0.2963
# Epoch 24: val_accuracy did not improve from 0.89076
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.8691 - auc: 0.9441 - loss: 0.3038 - val_accuracy: 0.8891 - val_auc: 0.9606 - val_loss: 0.2590
# Epoch 25/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8701 - auc: 0.9452 - loss: 0.3012
# Epoch 25: val_accuracy did not improve from 0.89076
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8691 - auc: 0.9449 - loss: 0.3014 - val_accuracy: 0.8878 - val_auc: 0.9608 - val_loss: 0.2585
# Epoch 26/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8745 - auc: 0.9486 - loss: 0.2918
# Epoch 26: val_accuracy improved from 0.89076 to 0.89161, saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
#
# Epoch 26: finished saving model to /home/optimalako/Projet/SAE/artifacts/gender_model_best.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.8735 - auc: 0.9477 - loss: 0.2939 - val_accuracy: 0.8916 - val_auc: 0.9612 - val_loss: 0.2552
# Epoch 27/30
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8712 - auc: 0.9466 - loss: 0.2970
# Epoch 27: val_accuracy did not improve from 0.89161
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.8715 - auc: 0.9466 - loss: 0.2969 - val_accuracy: 0.8895 - val_auc: 0.9609 - val_loss: 0.2586
# Epoch 28/30
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8727 - auc: 0.9481 - loss: 0.2936
# Epoch 28: val_accuracy did not improve from 0.89161
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8719 - auc: 0.9473 - loss: 0.2952 - val_accuracy: 0.8891 - val_auc: 0.9610 - val_loss: 0.2564
# Epoch 29/30
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8708 - auc: 0.9443 - loss: 0.3031
# Epoch 29: val_accuracy did not improve from 0.89161
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8726 - auc: 0.9462 - loss: 0.2980 - val_accuracy: 0.8887 - val_auc: 0.9610 - val_loss: 0.2569
# Epoch 30/30
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8738 - auc: 0.9470 - loss: 0.2963
# Epoch 30: val_accuracy did not improve from 0.89161
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.8708 - auc: 0.9459 - loss: 0.2989 - val_accuracy: 0.8912 - val_auc: 0.9612 - val_loss: 0.2546
# Restoring model weights from the end of the best epoch: 26.

# %% [markdown]
# ## 11. Visualisation de l'Entraînement

# %%
def plot_training_history(warmup_hist, finetune_hist):
    """Visualise l'historique d'entraînement."""
    combined_acc = warmup_hist.history["accuracy"] + finetune_hist.history["accuracy"]
    combined_val_acc = (
        warmup_hist.history["val_accuracy"] + finetune_hist.history["val_accuracy"]
    )
    combined_auc = warmup_hist.history["auc"] + finetune_hist.history["auc"]
    combined_val_auc = warmup_hist.history["val_auc"] + finetune_hist.history["val_auc"]
    combined_loss = warmup_hist.history["loss"] + finetune_hist.history["loss"]
    combined_val_loss = (
        warmup_hist.history["val_loss"] + finetune_hist.history["val_loss"]
    )

    epochs = range(1, len(combined_acc) + 1)
    warmup_end = len(warmup_hist.history["accuracy"])

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Accuracy
    axes[0].plot(epochs, combined_acc, "b-", label="Train", linewidth=2)
    axes[0].plot(epochs, combined_val_acc, "r-", label="Val", linewidth=2)
    axes[0].axvline(x=warmup_end, color="gray", linestyle="--", label="Fine-tuning")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Accuracy")
    axes[0].set_title("Accuracy")
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    # AUC
    axes[1].plot(epochs, combined_auc, "b-", label="Train", linewidth=2)
    axes[1].plot(epochs, combined_val_auc, "r-", label="Val", linewidth=2)
    axes[1].axvline(x=warmup_end, color="gray", linestyle="--", label="Fine-tuning")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("AUC")
    axes[1].set_title("AUC-ROC")
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    # Loss
    axes[2].plot(epochs, combined_loss, "b-", label="Train", linewidth=2)
    axes[2].plot(epochs, combined_val_loss, "r-", label="Val", linewidth=2)
    axes[2].axvline(x=warmup_end, color="gray", linestyle="--", label="Fine-tuning")
    axes[2].set_xlabel("Epoch")
    axes[2].set_ylabel("Loss")
    axes[2].set_title("Binary Cross-Entropy Loss")
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(ARTIFACTS_DIR / "gender_training_history.png", dpi=150)
    plt.show()

    best_val_acc = max(combined_val_acc)
    best_epoch = combined_val_acc.index(best_val_acc) + 1
    print(f"\nMeilleure Val Accuracy: {best_val_acc:.4f} (epoch {best_epoch})")
    print(f"Meilleur Val AUC: {max(combined_val_auc):.4f}")


plot_training_history(warmup_history, finetune_history)
# Out:
# Meilleure Val Accuracy: 0.8916 (epoch 38)
# Meilleur Val AUC: 0.9612

# %% [markdown]
# ## 12. Évaluation sur le Test Set

# %%
# Charger le meilleur modèle
best_model = keras.models.load_model(ARTIFACTS_DIR / "gender_model_best.keras")

# Évaluation
test_results = best_model.evaluate(test_ds, verbose=1)
print(f"\nRésultats sur le test set:")
print(f"  - Loss: {test_results[0]:.4f}")
print(f"  - Accuracy: {test_results[1]:.4f} ({test_results[1]*100:.2f}%)")
print(f"  - AUC: {test_results[2]:.4f}")
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.8950 - auc: 0.9622 - loss: 0.2503
#
# Résultats sur le test set:
#   - Loss: 0.2503
#   - Accuracy: 0.8950 (89.50%)
#   - AUC: 0.9622

# %%
# Prédictions détaillées
y_pred_proba = best_model.predict(test_ds, verbose=1).flatten()
y_pred = (y_pred_proba > 0.5).astype(int)
y_true = y_test

# Métriques
accuracy = np.mean(y_pred == y_true)
f1 = f1_score(y_true, y_pred)

print(f"\nMétriques détaillées:")
print(f"  - Accuracy: {accuracy:.4f}")
print(f"  - F1 Score: {f1:.4f}")
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step
#
# Métriques détaillées:
#   - Accuracy: 0.8950
#   - F1 Score: 0.8880

# %%
# Rapport de classification
print("\nRapport de classification:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES))
# Out:
# Rapport de classification:
#               precision    recall  f1-score   support
#
#         Male       0.89      0.92      0.90      1239
#       Female       0.90      0.87      0.89      1132
#
#     accuracy                           0.89      2371
#    macro avg       0.90      0.89      0.89      2371
# weighted avg       0.90      0.89      0.89      2371

# %% [markdown]
# ## 13. Courbes ROC et Precision-Recall

# %%
# Courbe ROC
fpr, tpr, thresholds_roc = roc_curve(y_true, y_pred_proba)
roc_auc = auc(fpr, tpr)

# Courbe Precision-Recall
precision, recall, thresholds_pr = precision_recall_curve(y_true, y_pred_proba)
pr_auc = auc(recall, precision)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ROC
axes[0].plot(fpr, tpr, "b-", linewidth=2, label=f"ROC (AUC = {roc_auc:.4f})")
axes[0].plot([0, 1], [0, 1], "k--", linewidth=1, label="Random")
axes[0].fill_between(fpr, tpr, alpha=0.2)
axes[0].set_xlabel("False Positive Rate")
axes[0].set_ylabel("True Positive Rate")
axes[0].set_title("Courbe ROC")
axes[0].legend(loc="lower right")
axes[0].grid(True, alpha=0.3)

# Precision-Recall
axes[1].plot(recall, precision, "g-", linewidth=2, label=f"PR (AUC = {pr_auc:.4f})")
axes[1].fill_between(recall, precision, alpha=0.2, color="green")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Courbe Precision-Recall")
axes[1].legend(loc="lower left")
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(ARTIFACTS_DIR / "gender_roc_pr_curves.png", dpi=150)
plt.show()

print(f"AUC-ROC: {roc_auc:.4f}")
print(f"AUC-PR: {pr_auc:.4f}")
# Out:
# AUC-ROC: 0.9623
# AUC-PR: 0.9584

# %% [markdown]
# ## 14. Matrice de Confusion

# %%
# Matrice de confusion
cm = confusion_matrix(y_true, y_pred)
cm_normalized = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Counts
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES,
    ax=axes[0],
    annot_kws={"size": 16},
)
axes[0].set_xlabel("Prédit")
axes[0].set_ylabel("Réel")
axes[0].set_title("Matrice de Confusion (counts)")

# Normalized
sns.heatmap(
    cm_normalized,
    annot=True,
    fmt=".3f",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES,
    ax=axes[1],
    annot_kws={"size": 16},
)
axes[1].set_xlabel("Prédit")
axes[1].set_ylabel("Réel")
axes[1].set_title("Matrice de Confusion (normalisée)")

plt.tight_layout()
plt.savefig(ARTIFACTS_DIR / "gender_confusion_matrix.png", dpi=150)
plt.show()

# Métriques dérivées
tn, fp, fn, tp = cm.ravel()
print(f"\nTrue Negatives (Male correct): {tn}")
print(f"False Positives (Male as Female): {fp}")
print(f"False Negatives (Female as Male): {fn}")
print(f"True Positives (Female correct): {tp}")
# Out:
# True Negatives (Male correct): 1135
# False Positives (Male as Female): 104
# False Negatives (Female as Male): 145
# True Positives (Female correct): 987

# %% [markdown]
# ## 15. Analyse de la Confiance

# %%
# Créer DataFrame des résultats
results_df = pd.DataFrame(
    {
        "true": y_true,
        "predicted": y_pred,
        "true_name": [GENDER_MAP[y] for y in y_true],
        "predicted_name": [GENDER_MAP[y] for y in y_pred],
        "correct": y_pred == y_true,
        "confidence": np.where(y_pred == 1, y_pred_proba, 1 - y_pred_proba),
    }
)

# Distribution de la confiance
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Par correctitude
correct_conf = results_df[results_df["correct"]]["confidence"]
incorrect_conf = results_df[~results_df["correct"]]["confidence"]

axes[0].hist(
    correct_conf,
    bins=30,
    alpha=0.7,
    label=f"Correct (n={len(correct_conf)})",
    color="green",
)
axes[0].hist(
    incorrect_conf,
    bins=30,
    alpha=0.7,
    label=f"Incorrect (n={len(incorrect_conf)})",
    color="red",
)
axes[0].set_xlabel("Confiance")
axes[0].set_ylabel("Fréquence")
axes[0].set_title("Distribution de la confiance")
axes[0].legend()

# Par classe prédite
male_conf = results_df[results_df["predicted"] == 0]["confidence"]
female_conf = results_df[results_df["predicted"] == 1]["confidence"]

axes[1].hist(
    male_conf, bins=30, alpha=0.7, label=f"Male (n={len(male_conf)})", color="#4C72B0"
)
axes[1].hist(
    female_conf,
    bins=30,
    alpha=0.7,
    label=f"Female (n={len(female_conf)})",
    color="#DD8452",
)
axes[1].set_xlabel("Confiance")
axes[1].set_ylabel("Fréquence")
axes[1].set_title("Confiance par genre prédit")
axes[1].legend()

plt.tight_layout()
plt.show()

print(f"Confiance moyenne (correct): {correct_conf.mean():.3f}")
print(f"Confiance moyenne (incorrect): {incorrect_conf.mean():.3f}")
# Out:
# Confiance moyenne (correct): 0.907
# Confiance moyenne (incorrect): 0.712

# %% [markdown]
# ## 16. Exemples de Prédictions

# %%
def show_predictions(model, filepaths, true_labels, n_samples=12):
    """Affiche une grille de prédictions."""
    indices = np.random.choice(len(filepaths), n_samples, replace=False)

    fig, axes = plt.subplots(3, 4, figsize=(16, 12))

    for idx, ax in zip(indices, axes.flat):
        img = Image.open(filepaths[idx]).convert("RGB").resize((IMG_SIZE, IMG_SIZE))
        img_array = np.array(img, dtype=np.float32)  # En [0, 255]

        proba = model.predict(img_array[np.newaxis, ...], verbose=0)[0, 0]
        pred = int(proba > 0.5)
        conf = proba if pred == 1 else 1 - proba
        true = true_labels[idx]

        # Afficher l'image originale (normalisée en [0, 1])
        ax.imshow(img_array / 255.0)
        color = "green" if pred == true else "red"
        ax.set_title(
            f"Réel: {GENDER_MAP[true]}\nPrédit: {GENDER_MAP[pred]} ({conf:.2f})",
            color=color,
            fontsize=10,
        )
        ax.axis("off")

    plt.suptitle(
        "Exemples de prédictions (vert: correct, rouge: incorrect)", fontsize=14
    )
    plt.tight_layout()
    plt.savefig(ARTIFACTS_DIR / "gender_predictions_examples.png", dpi=150)
    plt.show()


show_predictions(best_model, X_test, y_test)
# Out:
# 2026-01-18 12:55:14.221185: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:55:14.307606: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:55:14.730913: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-18 12:55:14.817273: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.

# %% [markdown]
# ## 17. Sauvegarde du Modèle Final

# %%
# Sauvegarder le modèle final
final_model_path = ARTIFACTS_DIR / "gender_model_final.keras"
best_model.save(final_model_path)
print(f"Modèle sauvegardé: {final_model_path}")

# Sauvegarder les infos du modèle
import json

model_info = {
    "img_size": IMG_SIZE,
    "classes": CLASS_NAMES,
    "class_map": {str(k): v for k, v in GENDER_MAP.items()},
    "threshold": 0.5,
    "input_range": [0, 255],  # Plage des valeurs d'entrée attendues
}

with open(ARTIFACTS_DIR / "gender_model_info.json", "w") as f:
    json.dump(model_info, f, indent=2)
print(f"Infos du modèle sauvegardées")
# Out:
# Modèle sauvegardé: /home/optimalako/Projet/SAE/artifacts/gender_model_final.keras
# Infos du modèle sauvegardées

# %%
# Conversion en TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

tflite_path = ARTIFACTS_DIR / "gender_model.tflite"
with open(tflite_path, "wb") as f:
    f.write(tflite_model)

print(f"Modèle TFLite sauvegardé: {tflite_path}")
print(f"Taille: {tflite_path.stat().st_size / 1024 / 1024:.2f} MB")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpuybucp1x/assets
# INFO:tensorflow:Assets written to: /tmp/tmpuybucp1x/assets
# Saved artifact at '/tmp/tmpuybucp1x'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_image')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   124000617857872: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   124000617861904: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   124005769031568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124280720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124280336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124281488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124281680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124281872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124278224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124281296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124282256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124282832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124278992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124283216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124280912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124282640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124283024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124281104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124283792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124282448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124284560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124282064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124283984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124284368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124284944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124285520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124284752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124284176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124285328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124285904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124286480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124285712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124286864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124283600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124286288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124286672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124285136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124287440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124286096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124288208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124280528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124287632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124288016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124288592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124289168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124288400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124287824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124288976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124289552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124290128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124289360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124290512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124287248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124289936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124290320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124288784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124291088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124289744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124291856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124292048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124291472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124290704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124292432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124293008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124291664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124291280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124292816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124293392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124293968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124293200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124293584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124292240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124292624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124293776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620840144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620840336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124290896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123998124287056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620838992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620839184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620839568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620840912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620841488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620840720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620839376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620841296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620841872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620842448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620841680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620842832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620839760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620842256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620842640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620841104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620843408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620842064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620844176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620844368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620843792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620843024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620844752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620845328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620843984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620843600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620845136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620845712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620846288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620845520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620846672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620844560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620846096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620846480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620844944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620847248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620845904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620848016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620843216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620847440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620847824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620848400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620848976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620848208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620847632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620848784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620849360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620849936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620849168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620850320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620847056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620849744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620850128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620848592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620850896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620849552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620851664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620851856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620851280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620850512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620852240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620852816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620851472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620851088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620852624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620853200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620853776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620853008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620854160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620852048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620853584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620853968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620854736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620854928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620854544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620855120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620846864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620854352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619676880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620852432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000620850704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619676496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619676688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619676112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619677456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619678032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619677264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619678416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619675728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619677840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619678224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619677072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619678992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619677648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619679760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619675920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619679184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619679568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619680144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619680720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619679952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619679376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619680528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619681104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619681680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619680912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619682064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619678800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619681488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619681872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619680336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619682640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619681296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619683408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619683600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619683024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619682256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619683984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619684560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619683216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619682832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619684368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619684944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619685520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619684752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619685904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619683792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619685328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619685712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619684176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619686480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619685136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619687248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619687440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619686864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619686096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619687824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619688400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619687056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619686672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619688208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619688784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619689360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619688592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619689744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619687632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619689168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619689552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619688016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619690320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619688976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619691088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619686288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619690896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619691280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619690128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619689936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619691664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619690512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619691472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619678608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619691856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000619690704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618546960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618546576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618545808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618545424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618545616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618547152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618545232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618547920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618548112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618547536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618546768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618548496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618549072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618547728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618547344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618548880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618549456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618550032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618549264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618550416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618548304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618549840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618550224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618548688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618550992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618549648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618551760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618551952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618551376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618550608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618552336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618552912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618551568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618551184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618552720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618553296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618553872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618553104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618554256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618552144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618553680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618554064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618552528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618554832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618553488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618555600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618555792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618555216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618554448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618556176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618556752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618555408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618555024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618556560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618557136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618557712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618556944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618558096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618555984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618557520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618557904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618556368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618558672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618557328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618559440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618554640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618558864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618559248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618559824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618560400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618559056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618560208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618558480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618560976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618561168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618546192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618559632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618560592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618560784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000617727184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618558288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000618560016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000617727568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124000617727376: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modèle TFLite sauvegardé: /home/optimalako/Projet/SAE/artifacts/gender_model.tflite
# Taille: 4.66 MB
# W0000 00:00:1768737324.916719   38776 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1768737324.916740   38776 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1768737325.026334   38776 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled

# %% [markdown]
# ## 18. Résumé des Performances

# %%
print("=" * 60)
print("RÉSUMÉ DU MODÈLE DE CLASSIFICATION DE GENRE")
print("=" * 60)
print(f"\nArchitecture: EfficientNetB0 + Dense Head")
print(f"Input size: {IMG_SIZE}x{IMG_SIZE}x3")
print(f"Classes: {CLASS_NAMES}")
print(
    f"Dataset: {len(df)} images (train: {len(X_train)}, val: {len(X_val)}, test: {len(X_test)})"
)
print(f"\nPerformances sur le test set:")
print(f"  - Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")
print(f"  - F1 Score: {f1:.4f}")
print(f"  - AUC-ROC: {roc_auc:.4f}")
print(f"  - AUC-PR: {pr_auc:.4f}")
print(f"\nFichiers sauvegardés:")
print(f"  - {final_model_path}")
print(f"  - {tflite_path}")
print("=" * 60)
# Out:
# ============================================================
# RÉSUMÉ DU MODÈLE DE CLASSIFICATION DE GENRE
# ============================================================
#
# Architecture: EfficientNetB0 + Dense Head
# Input size: 128x128x3
# Classes: ['Male', 'Female']
# Dataset: 23708 images (train: 18966, val: 2371, test: 2371)
#
# Performances sur le test set:
#   - Accuracy: 0.8950 (89.50%)
#   - F1 Score: 0.8880
#   - AUC-ROC: 0.9623
#   - AUC-PR: 0.9584
#
# Fichiers sauvegardés:
#   - /home/optimalako/Projet/SAE/artifacts/gender_model_final.keras
#   - /home/optimalako/Projet/SAE/artifacts/gender_model.tflite
# ============================================================
